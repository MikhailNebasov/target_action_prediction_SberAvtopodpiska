# %%
import pandas as pd

# %%
df = pd.read_csv('E:/Datasets/target_action_prediction_SberAvtopodpiska/ga_hits.csv')
df.head(10)
# Out:
#                                   session_id    hit_date   hit_time  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23   597864.0
# 1  7750352294969115059.1640271109.1640271109  2021-12-23   597331.0
# 2   885342191847998240.1640235807.1640235807  2021-12-23   796252.0
# 3   142526202120934167.1640211014.1640211014  2021-12-23   934292.0
# 4  3450086108837475701.1640265078.1640265078  2021-12-23   768741.0
# 5  6466333295973247896.1640246168.1640246168  2021-12-23   704194.0
# 6   281215510786615563.1640245516.1640245516  2021-12-23   911854.0
# 7  4024492994895054107.1640269084.1640269084  2021-12-23  1071804.0
# 8   555009234841130092.1640256620.1640256620  2021-12-23  1013899.0
# 9  2692901778487480807.1640206845.1640206845  2021-12-23        0.0
#
#    hit_number hit_type           hit_referer  \
# 0          30    event                   NaN
# 1          41    event                   NaN
# 2          49    event                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15726470 entries, 0 to 15726469
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      object
#  1   hit_date        object
#  2   hit_time        float64
#  3   hit_number      int64
#  4   hit_type        object
#  5   hit_referer     object
#  6   hit_page_path   object
#  7   event_category  object
#  8   event_action    object
#  9   event_label     object
#  10  event_value     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.3+ GB

# %%
df.describe(include='all')
# Out:
#                                        session_id    hit_date      hit_time  \
# count                                    15726470    15726470  6.566148e+06
# unique                                    1734610         226           NaN
# top     5442565791571325612.1632449195.1632449195  2021-05-24           NaN
# freq                                          768      513035           NaN
# mean                                          NaN         NaN  2.091050e+05
# std                                           NaN         NaN  4.032110e+05
# min                                           NaN         NaN  0.000000e+00
# 25%                                           NaN         NaN  2.412000e+04
# 50%                                           NaN         NaN  8.994100e+04
# 75%                                           NaN         NaN  2.195352e+05
# max                                           NaN         NaN  1.315688e+07
#
# ...

# %%
df2 = pd.read_csv('E:/Datasets/target_action_prediction_SberAvtopodpiska/ga_sessions.csv', low_memory=False)
df2.head(10)
# Out:
#                                   session_id              client_id  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.1637753791
# 1   905544597018549464.1636867290.1636867290   210838531.1636867288
# 2  9055446045651783499.1640648526.1640648526  2108385331.1640648523
# 3  9055447046360770272.1622255328.1622255328  2108385564.1622255328
# 4  9055447046360770272.1622255345.1622255345  2108385564.1622255328
# 5  9055447192389856083.1622453074.1622453074  2108385598.1622453075
# 6  9055455318486370642.1640843788.1640843788  2108387490.1640843602
# 7  9055461992850812764.1626107740.1626107740  2108389044.1626107740
# 8  9055462349345527315.1638536723.1638536723  2108389127.1638536723
# 9  9055466554104774132.1624800757.1624800757  2108390106.1624800756
#
#    visit_date visit_time  visit_number            utm_source utm_medium  \
# 0  2021-11-24   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1  2021-11-14   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860042 entries, 0 to 1860041
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   session_id                object
#  1   client_id                 object
#  2   visit_date                object
#  3   visit_time                object
#  4   visit_number              int64
#  5   utm_source                object
#  6   utm_medium                object
#  7   utm_campaign              object
#  8   utm_adcontent             object
#  9   utm_keyword               object
#  10  device_category           object
#  11  device_os                 object
#  12  device_brand              object
#  13  device_model              object
#  14  device_screen_resolution  object
#  15  device_browser            object
#  16  geo_country               object
#  17  geo_city                  object
# dtypes: int64(1), object(17)
# memory usage: 255.4+ MB

# %%
df2.describe(include='all')
# Out:
#                                        session_id              client_id  \
# count                                     1860042                1860042
# unique                                    1860042                1391719
# top     9055434745589932991.1637753792.1637753792  1750498477.1629450062
# freq                                            1                    462
# mean                                          NaN                    NaN
# std                                           NaN                    NaN
# min                                           NaN                    NaN
# 25%                                           NaN                    NaN
# 50%                                           NaN                    NaN
# 75%                                           NaN                    NaN
# max                                           NaN                    NaN
#
#         visit_date visit_time  visit_number            utm_source utm_medium  \
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df2.duplicated().any()
# Out:
# False

# %%
df.isna().any()
# Out:
# session_id        False
# hit_date          False
# hit_time           True
# hit_number        False
# hit_type          False
# hit_referer        True
# hit_page_path     False
# event_category    False
# event_action      False
# event_label        True
# event_value        True
# dtype: bool

# %%
df2.isna().any()
# Out:
# session_id                  False
# client_id                   False
# visit_date                  False
# visit_time                  False
# visit_number                False
# utm_source                   True
# utm_medium                  False
# utm_campaign                 True
# utm_adcontent                True
# utm_keyword                  True
# device_category             False
# device_os                    True
# device_brand                 True
# device_model                 True
# device_screen_resolution    False
# device_browser              False
# geo_country                 False
# geo_city                    False
# dtype: bool

# %% [markdown]
# # 1. EDA.

# %% [markdown]
# 1.1. Датасет представлен двумя таблицами. В обеих таблицах отсутствуют дубли.
#
# 1.2. Исходя из количества уникальных строк сессий в обеих таблицах и общего количества строк хитов становится очевидно, что существуют сессии, как без единого хита, так и сессии где хитов 1 и более. Однако поскольку по условиям задания модель принимает только аттрибуты вида utm_*, device_*, geo_*, то фактически нам из таблицы хитов нужны только значения атрибута event_action, который содержит целевую переменную, а также session_id по которому объединяются таблицы.
#
# 1.3. Атрибуты hit_date, hit_time, hit_number, hit_type, hit_referer, hit_page_path, event_category, event_label, event_value не являются аттрибутами модели, поэтому фичи на удаление.
#
# 1.4. Идентификатор сессии session_id нужен для объединения таблиц, поэтому после объединения фича идет на удаление.
#
# 1.5. client_id, visit_date, visit_time, visit_number не являются аттрибутами модели, поэтому фичи на удаление.
#
# 1.6. Информация о канале привлечения utm_source содержит 97 пропусков. При 293 уникальных значениях имеет смысл замены на наиболее часто встречающийся.
#
# 1.7. В типе привлечения utm_medium отсутствуют пропуски.
#
# 1.8. Идентификатор рекламной компании utm_campaign содержит 219603 пропуска, что составляет около 12% от общего количества. Удаление этой фичи не видится целесообразным, однако например для значения  utm_source = BHcvLfOaCWvWTykYqHVe, что составляет около половины всех пропусков какие-либо данные отсутствуют, поэтому в рекламной компании все пропуски будем заменять на значение other.
#
# 1.9. Атрибут utm_adcontent содержит 335615 пропусков, что составляет около 18% от общего количества. Удаление этой фичи не видится целесообразным, однако например для значения  utm_source = BHcvLfOaCWvWTykYqHVe, что составляет около трети всех пропусков какие-либо данные отсутствуют, поэтому в utm_adcontent все пропуски будем заменять на значение other.
#
# 1.10. Атрибут utm_keyword содержит пропусков более 50% от общего количества. Фича на удаление.
#
# 1.11. Атрибут device_category не содержит пропусков.
#
# 1.12. Атрибут device_os содержит пропусков более 50% от общего количества. Фича на удаление.
#
# 1.13. Атрибут device_brand содержит 367178 пропусков, что составляет около 20% от общего количества. Удаление этой фичи не видится целесообразным, поэтому в device_brand все пропуски будем заменять на значение other.
#
# 1.14.Атрибут device_model подавляющее количество пропусков. Фича на удаление.
#
# 1.15. Атрибуты device_screen_resolution, device_browser, geo_country, geo_city не содержат пропусков.
